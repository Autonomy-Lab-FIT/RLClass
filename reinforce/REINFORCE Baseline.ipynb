# %% [markdown]
# # Policy Gradients: REINFORCE Baseline with LunarLander

# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import gymnasium as gym
import numpy as np
from IPython import display

# %%
# check and use GPU if available if not use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### LunarLander
#
# LunarLander is an OpenAI gym environment (env). In this env the agent tries to land a space craft safely on the ground by firing the main, left, or right engine. The agent receives a reward for navigating to the landing pad and turning off the engine, a large reward for a safe landing, a large negative reward for an unsafe landing, and a small negative reward for using the engines. There are discrete and continuous versions of LunarLander.

# %%
render_in_notebook = False # can be very laggy if True, set to False for faster training and to pop up in a separate window

#env = gym.make('LunarLander-v3', render_mode='rgb_array' if render_in_notebook else 'human')
env = gym.make('LunarLanderContinuous-v3', render_mode='rgb_array' if render_in_notebook else 'human')
env.reset(seed=0)

for i in range(200):
    action = env.action_space.sample()
    obs, reward, done, info, prob = env.step(action)
    if render_in_notebook:
        plt.imshow(env.render())
        plt.axis('off')
        display.clear_output(wait=True)
        display.display(plt.gcf())
    if done:
        env.reset()
        
env.close()

# %% [markdown]
# ### Policy Gradient Methods
#
# In policy gradient methods, we update the policy directly. Ie we parameterize the policy and perform gradient descent updates on the policy parameters seeking to improve the policy. This is in contrast to section 3 where we learned estimates of the state or action-values. Then we extracted a policy based on those values, like with the epsilon greedy DQN policy.
#
# ### Discrete vs. Continuous Action Spaces
#
# PG methods can work in discrete and continuous action spaces. The DQN method we went over in section three required discrete action spaces: ie a limited number of actions. In continuous actions spaces there are an infinite number of actions as the action can be any value in a range. Continuous action spaces are often parameterized by a probability distribution and we learn the parameters of the distribution. For example we assume the actions come from a Gaussian distribution and try to learn the mean and standard deviation of the Gaussian that leads to the best policy.
#
# ### REINFORCE with Lunar Lander
#
# In this example, we will solve the discrete version of Lunar Lander using the REINFORCE with baseline method.

# %% [markdown]
# ### 1. Initialise the Agent

# %%
# Defines policy network pi_theta(a|s)
# Discrete actions: pi_theta(a|s) = softmax(f_theta(s))
# class ActorNet(nn.Module):
#     def __init__(self, state_size, action_size, hidden_size):
#         super(ActorNet, self).__init__()
#         self.dense_layer_1 = nn.Linear(state_size, hidden_size)
#         self.dense_layer_2 = nn.Linear(hidden_size, hidden_size)
#         self.output = nn.Linear(hidden_size, action_size)
    
#     def forward(self, x):
#         x = torch.clamp(x,-1.1,1.1)
#         x = F.relu(self.dense_layer_1(x))
#         x = F.relu(self.dense_layer_2(x))
#         return F.softmax(self.output(x),dim=-1) #-1 to take softmax of last dimension

# Continuous actions: pi_theta(a|s) = N(mu_theta(s), sigma_theta(s))
class ActorNet(nn.Module):
    def __init__(self, state_size, action_size, hidden_size):
        super(ActorNet, self).__init__()
        self.dense_layer_1 = nn.Linear(state_size, hidden_size)
        self.dense_layer_2 = nn.Linear(hidden_size, hidden_size)

        # NN outputs distribution with mean mu_theta(s) and std. dev. simga_theta(s)
        self.output_mu = nn.Linear(hidden_size, action_size)   # mu_theta(s)
        self.output_sigma = nn.Linear(hidden_size, action_size)   # std_theta(s)
    
    def forward(self, x):
        x = torch.clamp(x,-1.1,1.1)
        x = F.relu(self.dense_layer_1(x))
        x = F.relu(self.dense_layer_2(x))

        mu = self.output_mu(x)

        # Gaussian distribution must have positive std. dev sigma
        # Output as log(sigma), then inverse log = exp = pos
        log_sigma = self.output_sigma(x)

        # Undo log by exp to ensure positive
        sigma = torch.exp(log_sigma)

        return mu, sigma

# NN to predict value V(s)
class ValueFunctionNet(nn.Module):
    def __init__(self, state_size, hidden_size):
        super(ValueFunctionNet, self).__init__()
        self.dense_layer_1 = nn.Linear(state_size, hidden_size)
        self.dense_layer_2 = nn.Linear(hidden_size, hidden_size)
        self.output = nn.Linear(hidden_size, 1)
    
    def forward(self, x):
        x = torch.clamp(x,-1.1,1.1)
        x = F.relu(self.dense_layer_1(x))
        x = F.relu(self.dense_layer_2(x))
        return self.output(x)

# %%
class PGAgent():
    def __init__(self, state_size, action_size, hidden_size, actor_lr, vf_lr, discount ):
        self.action_size = action_size
        
        self.actor_net = ActorNet(state_size, action_size, hidden_size).to(device) # pi_theta(a|s)
        self.vf_net = ValueFunctionNet(state_size, hidden_size).to(device)  # V(s)
        self.actor_optimizer = optim.Adam(self.actor_net.parameters(), lr=actor_lr)
        self.vf_optimizer = optim.Adam(self.vf_net.parameters(), lr=vf_lr)
        self.discount = discount
        
    def select_action(self, state, deterministic=False):
        #get action probs then randomly sample from the probabilities: a_t ~ pi_theta(.|s)
        with torch.no_grad():
            input_state = torch.FloatTensor(state).to(device)

            # # Discrete action selection 
            # action_probs = self.actor_net(input_state)  # pi_theta(a|s) = Softmax(f_theta(s))
            
            # #detach and turn to numpy to use with np.random.choice()
            # action_probs = action_probs.detach().cpu().numpy()
            ## Sample action from probabilities
            # action = np.random.choice(np.arange(self.action_size), p=action_probs)  # a_t ~ pi_theta(.|s)

            # return action

            # Continuous action selection
            # During training, sample an action from distribution
            # Sample action from normal distribution with mean (mu) and std dev (sigma)
            mu, sigma = self.actor_net(input_state)

            # After training, durectly use the mean
            if deterministic:
                action = mu
            else:     
                distribution = torch.distributions.Normal(mu, sigma)
                action = distribution.sample()

            # Get better results when clamping std. dev
            # Without clamping, rewards collapsed to -250 and remained flat
            # --> Policy was consistenly crashing 
            action = torch.clamp(action, -2.0, 2.0)

        # Continuous case: Need to convery pytorch tensor -> NumPy array
        return action.detach().cpu().numpy()

    def train(self, state_list, action_list, reward_list):

        #turn rewards into return
        trajectory_len = len(reward_list)
        return_array = np.zeros((trajectory_len,))

        # backwards return: G_t = r_t + gamma*G_t+1
        g_return = 0.
        for i in range(trajectory_len-1,-1,-1):
            g_return = reward_list[i] + self.discount*g_return
            return_array[i] = g_return
            
        # create tensors
        state_t = torch.FloatTensor(state_list).to(device)
        
        # Discrete action
        #action_t = torch.LongTensor(action_list).to(device).view(-1,1)

        # Continuous action
        action_t = torch.FloatTensor(action_list).to(device)
        
        return_t = torch.FloatTensor(return_array).to(device).view(-1,1)
        
        # get value function estimates: Predicts V(s)
        vf_t = self.vf_net(state_t).to(device)
        with torch.no_grad():

            # Calculate Adavantage: A_t = G_t - V(s)
            advantage_t = return_t - vf_t
        
        ###### Discrete action ##########
        # calculate actor loss
        # Get pi_theta(a|s)
        # selected_action_prob = self.actor_net(state_t).gather(1, action_t)

        # # REINFORCE loss: doesn't subtract baseline - higher variance
        # #actor_loss = torch.mean(-torch.log(selected_action_prob) * return_t)

        # # REINFORCE Baseline loss:
        # # = E [log pi_theta(at|st)(Gt-V(s))] : minimizing -log = maximizing expected return
        # actor_loss = torch.mean(-torch.log(selected_action_prob) * advantage_t)

        ### Continuous Action #######
        # Get mu(s) and sigma(s) 
        mu, sigma = self.actor_net(state_t)
        distribution = torch.distributions.Normal(mu, sigma)

        # .log_prob returns the log probability evaluated at value (action_t)
        # --> Returns log probability for sampled action
        log_prob = distribution.log_prob(action_t).sum(dim=1, keepdim=True)

        # Actor loss same as discrete: min - log = max expected return
        # = E [log pi_theta(at|st)(Gt-V(s))] 
        actor_loss = torch.mean(-log_prob * advantage_t)


        # theta <-- theta + alpha*ghat
        self.actor_optimizer.zero_grad()    # Clear old grads
        actor_loss.backward()       # backprop: grad of actor loss wrt actor params
        self.actor_optimizer.step()     # update actor params

        # calculate vf loss using MSE: (V(s)-Gt)^2
        loss_fn = nn.MSELoss()
        vf_loss = loss_fn(vf_t, return_t)
        
        self.vf_optimizer.zero_grad()
        vf_loss.backward()
        self.vf_optimizer.step() 
        
        return actor_loss.detach().cpu().numpy(), vf_loss.detach().cpu().numpy()

# %% [markdown]
# ### 2. Set up the environment

# %%
# initialize environment
env = gym.make('LunarLander-v3', render_mode='rgb_array')
env = gym.make('LunarLanderContinuous-v3', render_mode='rgb_array')


# ## Discrete env ###
# env = gym.make('LunarLander-v3')
# action_size = env.action_space.n
# state_size = env.observation_space.shape[0]

### Continuus action env ######
env = gym.make('LunarLanderContinuous-v3')
action_size = env.action_space.shape[0]
state_size = env.observation_space.shape[0]

# set seed
seed = 31
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# hyperparameters
episodes = 5000 # run agent for this many episodes
# hidden_size = 64 # number of units in NN hidden layers
hidden_size = 64
actor_lr = 0.002 # learning rate for actor
value_function_lr = 0.002 # learning rate for value function
discount = 0.99 # discount factor gamma value
reward_scale = 0.01 #scale reward by this amount

# create agent
agent = PGAgent(state_size, action_size, hidden_size, actor_lr, value_function_lr, discount)

# %% [markdown]
# ### 3. Train the Agent with REINFORCE with baseline

# %%
stats_rewards_list = [] # store stats for plotting in this
stats_every = 50 # print stats every this many episodes
total_reward = 0
timesteps = 0
episode_length = 0
stats_actor_loss, stats_vf_loss = 0., 0.

for ep in range(episodes):
    state, _ = env.reset(seed=seed)
    state_list, action_list, reward_list = [], [], []
    
    # stopping condition for training if agent reaches the amount of reward
    if len(stats_rewards_list) > stats_every and np.mean(stats_rewards_list[-stats_every:],axis=0)[1] > 190:
        print("Stopping at episode {} with average rewards of {} in last {} episodes".
            format(ep, np.mean(stats_rewards_list[-stats_every:],axis=0)[1], stats_every))
        break  

    # train in each episode until episode is done
    while True:
        timesteps += 1
        #env.render()
        # select an action from the agent's policy: at ~ pi_theta(.|st)
        action = agent.select_action(state, deterministic=False)
        
        # enter action into the env
        # step env, observe r_t^(i), s_t+1^(i)
        next_state, reward, done, _, _ = env.step(action)
        total_reward += reward
        episode_length += 1
        # store agent's trajectory
        state_list.append(state)
        action_list.append(action)
        reward_list.append(reward*reward_scale)
        
        # end episode early
        if total_reward < -250:
            done = 1
        
        if done:
            actor_loss, vf_loss = agent.train(state_list, action_list, reward_list)
            stats_rewards_list.append((ep, total_reward, episode_length))
            stats_actor_loss += actor_loss
            stats_vf_loss += vf_loss
            total_reward = 0
            episode_length = 0  
            if ep % stats_every == 0:
                print('Episode: {}'.format(ep),
                    'Timestep: {}'.format(timesteps),
                    'Total reward: {:.1f}'.format(np.mean(stats_rewards_list[-stats_every:],axis=0)[1]),
                    'Episode length: {:.1f}'.format(np.mean(stats_rewards_list[-stats_every:],axis=0)[2]),
                    'Actor Loss: {:.4f}'.format(stats_actor_loss/stats_every), 
                    'VF Loss: {:.4f}'.format(stats_vf_loss/stats_every))
                stats_actor_loss, stats_vf_loss = 0., 0.
            break        
        state = next_state
# Out:
# Episode: 0 Timestep: 120 Total reward: -229.3 Episode length: 120.0 Actor Loss: -0.0801 VF Loss: 0.0440
# Episode: 50 Timestep: 4795 Total reward: -151.3 Episode length: 93.5 Actor Loss: -0.5875 VF Loss: 0.4377
# Episode: 100 Timestep: 9475 Total reward: -99.1 Episode length: 93.6 Actor Loss: 0.0197 VF Loss: 0.1331
# Episode: 150 Timestep: 14500 Total reward: -97.7 Episode length: 100.5 Actor Loss: -0.0983 VF Loss: 0.1311
# Episode: 200 Timestep: 19979 Total reward: -68.7 Episode length: 109.6 Actor Loss: 0.1805 VF Loss: 0.1043
# Episode: 250 Timestep: 27477 Total reward: -61.3 Episode length: 150.0 Actor Loss: -0.0101 VF Loss: 0.0974
# Episode: 300 Timestep: 36275 Total reward: -47.4 Episode length: 176.0 Actor Loss: 0.0437 VF Loss: 0.0663
# Episode: 350 Timestep: 47197 Total reward: -120.8 Episode length: 218.4 Actor Loss: -0.2447 VF Loss: 0.2536
# Episode: 400 Timestep: 51991 Total reward: -241.4 Episode length: 95.9 Actor Loss: -0.1242 VF Loss: 0.4435
# Episode: 450 Timestep: 54666 Total reward: -255.8 Episode length: 53.5 Actor Loss: 0.0182 VF Loss: 0.0679
# Episode: 500 Timestep: 57928 Total reward: -255.1 Episode length: 65.2 Actor Loss: -0.0381 VF Loss: 0.0444
# Episode: 550 Timestep: 61150 Total reward: -255.3 Episode length: 64.4 Actor Loss: 0.0154 VF Loss: 0.0221
# Episode: 600 Timestep: 64593 Total reward: -255.7 Episode length: 68.9 Actor Loss: -0.0020 VF Loss: 0.0340
# Episode: 650 Timestep: 68035 Total reward: -255.1 Episode length: 68.8 Actor Loss: -0.0057 VF Loss: 0.0204
# Episode: 700 Timestep: 71784 Total reward: -255.1 Episode length: 75.0 Actor Loss: 0.0028 VF Loss: 0.0293
# Episode: 750 Timestep: 75667 Total reward: -256.0 Episode length: 77.7 Actor Loss: -0.0050 VF Loss: 0.0259
# Episode: 4400 Timestep: 4787891 Total reward: -252.5 Episode length: 3127.0 Actor Loss: -0.0032 VF Loss: 0.0051
# Episode: 4450 Timestep: 4943302 Total reward: -240.3 Episode length: 3108.2 Actor Loss: -0.0073 VF Loss: 0.0064
# Episode: 4500 Timestep: 5079134 Total reward: -208.0 Episode length: 2716.6 Actor Loss: -0.0241 VF Loss: 0.0382
# Episode: 4550 Timestep: 5095403 Total reward: -170.0 Episode length: 325.4 Actor Loss: 8669154304.0000 VF Loss: 0.2239
# Episode: 4600 Timestep: 5097762 Total reward: -256.4 Episode length: 47.2 Actor Loss: -5397.1201 VF Loss: 0.0223
# Episode: 4650 Timestep: 5100125 Total reward: -257.1 Episode length: 47.3 Actor Loss: 156.2441 VF Loss: 0.0228
# Episode: 4700 Timestep: 5102471 Total reward: -256.3 Episode length: 46.9 Actor Loss: 160.1516 VF Loss: 0.0185
# Episode: 4750 Timestep: 5104820 Total reward: -256.7 Episode length: 47.0 Actor Loss: 154.8944 VF Loss: 0.0107
# Episode: 4800 Timestep: 5107177 Total reward: -256.5 Episode length: 47.1 Actor Loss: -228.7220 VF Loss: 0.0264
# Episode: 4850 Timestep: 5109552 Total reward: -257.2 Episode length: 47.5 Actor Loss: 240.0202 VF Loss: 0.0203
# Episode: 4900 Timestep: 5111929 Total reward: -256.1 Episode length: 47.5 Actor Loss: 302.0602 VF Loss: 0.0179
# Episode: 4950 Timestep: 5114305 Total reward: -256.0 Episode length: 47.5 Actor Loss: 20.4603 VF Loss: 0.0206

# %% [markdown]
# ### 4. Plot the Scores

# %%
# plot stats
def get_running_stat(stat, stat_len):
    cum_sum = np.cumsum(np.insert(stat, 0, 0)) 
    return (cum_sum[stat_len:] - cum_sum[:-stat_len]) / stat_len

episode, r, l = np.array(stats_rewards_list).T
cum_r = get_running_stat(r, 10)
cum_l = get_running_stat(l, 10)

# plot rewards
plt.plot(episode[-len(cum_r):], cum_r)
plt.plot(episode, r, alpha=0.5)
plt.xlabel('Episode')
plt.ylabel('Episode Reward')
# Out:
# Text(0, 0.5, 'Episode Reward')

# %%
# plot episode lengths
plt.plot(episode[-len(cum_l):], cum_l)
plt.plot(episode, l, alpha=0.5)
plt.xlabel('Episode')
plt.ylabel('Episode Length')
# Out:
# Text(0, 0.5, 'Episode Length')

# %% [markdown]
# ### 5. Watch your Trained Agent!

# %%
render_in_notebook = False # can be very laggy if True, set to False for faster training and to pop up in a separate window

#env = gym.make('LunarLander-v3', render_mode='rgb_array' if render_in_notebook else 'human')
env = gym.make('LunarLanderContinuous-v3', render_mode='rgb_array' if render_in_notebook else 'human')
env.reset(seed=0)

done = False
while not done:
    #action = agent.select_action(state)
    # Modify action to directly use mean after training is done
    action = agent.select_action(state, deterministic=True)
    obs, reward, done, info, prob = env.step(action)
    if render_in_notebook:
        plt.imshow(env.render())
        plt.axis('off')
        display.clear_output(wait=True)
        display.display(plt.gcf())
    if done:
        env.reset()
        
env.close()
